# %% [markdown]
# Alessio's code for Kentucky water network
# ====

# %%
import wntr
from wntr.epanet.toolkit import EpanetException

import networkx as nx
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
import matplotlib.colors

import pickle

# %%
# just set a code for the color
def nodes_colors_dataframe(wn, highlighted_nodes):
    df = {}
    for node in wn.get_graph():        
        if 'Reservoir' in wn.get_node(node).node_type:
            df[node] = [3]
        elif 'Tank' in wn.get_node(node).node_type:
            df[node] = [2]  
        elif node in highlighted_nodes:
            df[node] = [0]            
        else:
            df[node] = [1]     
    return pd.DataFrame(data=df)


def print_wdn(wn, highlighted_nodes = [], filename = None):
    node_colors = nodes_colors_dataframe(wn, highlighted_nodes).loc[0, :]
    cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["red","yellow","cyan","blue"], gamma=0.8)
    fig, ax1 = plt.subplots(figsize=(25,25))
    ax1.axis('off')
    wntr.graphics.plot_network(wn, node_attribute=node_colors, node_size=250, node_range=[0,3], add_colorbar=False,
                               node_cmap=cmap, ax=ax1)#, title='Reservoirs and Tanks')
 
    if filename:
        plt.savefig(filename, format='eps', dpi=1000)

# %%
# load .inp file
code = "ky2"
filename = '../data/kentucky_water_distribution_networks/'+code+'.inp'
wn = wntr.network.WaterNetworkModel(filename)

# %%
# Print the WDN
print_wdn(wn)
# Out:
# /anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
type(wn)
# Out:
# wntr.network.model.WaterNetworkModel

# %%
# Get the NetworkX graph
G = wn.get_graph()

# %%
# Print node propreties
G.nodes(data=True)
# Out:
# NodeDataView({'J-1': {'pos': (4071494.75, 3449266.0), 'type': 'Junction'}, 'J-10': {'pos': (4076447.5, 3442551.0), 'type': 'Junction'}, 'J-100': {'pos': (4072563.25, 3440915.0), 'type': 'Junction'}, 'J-101': {'pos': (4073314.75, 3441013.0), 'type': 'Junction'}, 'J-102': {'pos': (4073394.5, 3441066.0), 'type': 'Junction'}, 'J-103': {'pos': (4069819.25, 3444045.0), 'type': 'Junction'}, 'J-104': {'pos': (4070024.99, 3443822.0), 'type': 'Junction'}, 'J-105': {'pos': (4077364.75, 3443709.0), 'type': 'Junction'}, 'J-106': {'pos': (4077362.5, 3443575.0), 'type': 'Junction'}, 'J-107': {'pos': (4072666.75, 3439223.0), 'type': 'Junction'}, 'J-108': {'pos': (4072163.25, 3438983.0), 'type': 'Junction'}, 'J-109': {'pos': (4074113.49, 3441093.0), 'type': 'Junction'}, 'J-11': {'pos': (4073076.25, 3436208.0), 'type': 'Junction'}, 'J-110': {'pos': (4074114.0, 3441011.0), 'type': 'Junction'}, 'J-111': {'pos': (4076834.26, 3440787.0), 'type': 'Junction'}, 'J-112': {'pos': (4077237.0, 3440801.0), 'type': 'Junction'}, 'J-113': {'pos': (4067497.24, 3436364.0), 'type': 'Junction'}, 'J-114': {'pos': (4066655.5, 3436365.0), 'type': 'Junction'}, 'J-115': {'pos': (4074430.25, 3440178.0), 'type': 'Junction'}, 'J-116': {'pos': (4074449.76, 3440667.0), 'type': 'Junction'}, 'J-117': {'pos': (4075282.5, 3441853.0), 'type': 'Junction'}, 'J-118': {'pos': (4075706.5, 3441842.0), 'type': 'Junction'}, 'J-119': {'pos': (4074309.74, 3436737.0), 'type': 'Junction'}, 'J-12': {'pos': (4073058.5, 3435706.0), 'type': 'Junction'}, 'J-120': {'pos': (4073982.5, 3436756.0), 'type':
# OutMultiEdgeDataView([('J-1', 'T-3', {'type': 'Pipe'}), ('J-1', 'J-62', {'type': 'Pipe'}), ('J-10', 'J-7', {'type': 'Pipe'}), ('J-10', 'J-614', {'type': 'Pipe'}), ('J-100', 'J-473', {'type': 'Pipe'}), ('J-101', 'J-102', {'type': 'Pipe'}), ('J-102', 'J-234', {'type': 'Pipe'}), ('J-103', 'J-576', {'type': 'Pipe'}), ('J-103', 'J-104', {'type': 'Pipe'}), ('J-104', 'J-78', {'type': 'Pipe'}), ('J-105', 'J-106', {'type': 'Pipe'}), ('J-105', 'J-746', {'type': 'Pipe'}), ('J-106', 'J-292', {'type': 'Pipe'}), ('J-106', 'J-603', {'type': 'Pipe'}), ('J-107', 'J-108', {'type': 'Pipe'}), ('J-108', 'J-107', {'type': 'Pipe'}), ('J-109', 'J-110', {'type': 'Pipe'}), ('J-109', 'J-639', {'type': 'Pipe'}), ('J-11', 'J-15', {'type': 'Pipe'}), ('J-11', 'J-12', {'type': 'Pipe'}), ('J-110', 'J-176', {'type': 'Pipe'}), ('J-111', 'J-371', {'type': 'Pipe'}), ('J-111', 'J-782', {'type': 'Pipe'}), ('J-111', 'J-690', {'type': 'Pipe'}), ('J-112', 'J-270', {'type': 'Pipe'}), ('J-113', 'J-114', {'type': 'Pipe'}), ('J-115', 'J-116', {'type': 'Pipe'}), ('J-116', 'J-181', {'type': 'Pipe'}), ('J-117', 'J-289', {'type': 'Pipe'}), ('J-117', 'J-118', {'type': 'Pipe'}), ('J-118', 'J-376', {'type': 'Pipe'}), ('J-119', 'J-460', {'type': 'Pipe'}), ('J-119', 'J-120', {'type': 'Pipe'}), ('J-12', 'J-6', {'type': 'Pipe'}), ('J-120', 'J-747', {'type': 'Pipe'}), ('J-121', 'J-587', {'type': 'Pipe'}), ('J-121', 'J-122', {'type': 'Pipe'}), ('J-122', 'J-200', {'type': 'Pipe'}), ('J-123', 'J-124', {'type': 'Pipe'}), ('J-123', 'J-151', {'type': 'Pipe'}), ('J-125', 'J-126', {'type': 'Pipe'}), ('J-126', 'J-451', {'type': 'Pipe'}), ('J-126', 'J-764', {'type': 'Pipe'}), ('J-127', 'J-430', {'type': 'Pipe'}), ('J-128', 'J-129', {'type': 'Pipe'}), ('J-128', 'J-93', {'type': 'Pipe'}), ('J-129', 'J-300', {'type': 'Pipe'}), ('J-129', 'J-178', {'type': 'Pipe'}), ('J-13', 'J-540', {'type': 'Pipe'}), ('J-13', 'J-311', {'type': 'Pipe'}), ('J-130', 'J-131', {'type': 'Pipe'}), ('J-131', 'J-224', {'type': 'Pipe'}), ('J-131', 'J-649', {'type': 'Pipe'}), ('J-132', 'J-121', {'type': 'Pipe'}), ('J-132', 'J-133', {'type': 'Pipe'}), ('J-134', 'J-45', {'type': 'Pipe'}), ('J-134', 'J-135', {'type': 'Pipe'}), ('J-135', 'J-264', {'type': 'Pipe'}), ('J-135', 'J-272', {'type': 'Pipe'}), ('J-136', 'J-782', {'type': 'Pipe'}), ('J-137', 'J-776', {'type': 'Pipe'}), ('J-137', 'J-778', {'type': 'Pipe'}), ('J-137', 'J-354', {'type': 'Pipe'}), ('J-138', 'J-485', {'type': 'Pipe'}), ('J-138', 'J-139', {'type': 'Pipe'}), ('J-139', 'J-218', {'type': 'Pipe'}), ('J-139', 'J-540', {'type': 'Pipe'}), ('J-14', 'J-311', {'type': 'Pipe'}), ('J-140', 'J-65', {'type': 'Pipe'}), ('J-140', 'J-141', {'type': 'Pipe'}), ('J-141', 'J-377', {'type': 'Pipe'}), ('J-142', 'J-557', {'type': 'Pipe'}), ('J-142', 'J-143', {'type': 'Pipe'}), ('J-144', 'J-551', {'type': 'Pipe'}), ('J-144', 'J-55', {'type': 'Pipe'}), ('J-145', 'J-327', {'type': 'Pipe'}), ('J-146', 'J-617', {'type': 'Pipe'}), ('J-146', 'J-103', {'type': 'Pipe'}), ('J-147', 'J-659', {'type': 'Pipe'}), ('J-147', 'J-148', {'type': 'Pipe'}), ('J-148', 'J-655', {'type': 'Pipe'}), ('J-148', 'J-250', {'type': 'Pipe'}), ('J-149', 'J-324', {'type': 'Pipe'}), ('J-149', 'J-150', {'type': 'Pipe'}), ('J-15', 'J-771', {'type': 'Pipe'}), ('J-15', 'J-16', {'type': 'Pipe'}), ('J-150', 'J-740', {'type': 'Pipe'}), ('J-151', 'J-152', {'type': 'Pipe'}), ('J-153', 'J-154', {'type': 'Pipe'}), ('J-153', 'J-3', {'type': 'Pipe'}), ('J-154', 'J-240', {'type': 'Pipe'}), ('J-155', 'J-156', {'type': 'Pipe'}), ('J-156', 'J-187', {'type': 'Pipe'}), ('J-156', 'J-415', {'type': 'Pipe'}), ('J-157', 'J-158', {'type': 'Pipe'}), ('J-158', 'J-570', {'type': 'Pipe'}), ('J-159', 'J-774', {'type': 'Pipe'}), ('J-159', 'J-160', {'type': 'Pipe'}), ('J-16', 'J-12', {'type': 'Pipe'}), ('J-161', 'J-66', {'type': 'Pipe'}), ('J-161', 'J-162', {'type': 'Pipe'}), ('J-163', 'J-738', {'type': 'Pipe'}), ('J-163', 'J-164', {'type': 'Pipe'}), ('J-164', 'J-394', {'type': 'Pipe'}), ('J-164', 'J-738', {'type': 'Pipe'}), ('J-165', 'J-787', {'t ...

# %%
# Load dynamics
filename = "../data/kentucky_water_distribution_networks/Ky2.pkl"
with open(filename, 'rb') as input_file:
    pollution = pickle.load(input_file)

# %%
pollution.keys()
# Out:
# dict_keys(['chemical_start_time', 'J-1', 'J-10', 'J-100', 'J-300', 'J-330', 'J-490'])

# %% [markdown]
# Bokeh version of the network
# ====

# %%
from bokeh.models.graphs import from_networkx, NodesAndLinkedEdges, EdgesAndLinkedNodes
from bokeh.models import Range1d, Plot, MultiLine, Circle, HoverTool
from bokeh.palettes import Spectral4
from bokeh.io import show, output_notebook, curdoc
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1919">Loading BokehJS ...</span>
#     </div>

# %%
# We could use figure here but don't want all the axes and titles
plot = Plot(x_range=Range1d(-6, 6), y_range=Range1d(-6, 6))

# Create a Bokeh graph from the NetworkX input using nx.spring_layout
graph = from_networkx(G, nx.layout.fruchterman_reingold_layout, seed=5, scale=5, center=(0,0))
plot.renderers.append(graph)

# Create nodes and edges
graph.node_renderer.glyph = Circle(size=15, fill_color=Spectral4[0])
graph.edge_renderer.glyph = MultiLine(line_alpha=1.6, line_width=4)

# green hover for both nodes and edges
graph.node_renderer.hover_glyph = Circle(size='sizes', fill_color='#abdda4')
graph.edge_renderer.hover_glyph = MultiLine(line_color='#abdda4', line_width=8)

# When we hover over nodes, highlight adjecent edges too
graph.selection_policy = NodesAndLinkedEdges()
graph.inspection_policy = EdgesAndLinkedNodes()

plot.add_tools(HoverTool())
show(plot)
# Out:
#   <div class="bk-root" id="910c98b5-b5ea-4741-b087-15af12000097" data-root-id="1922"></div>
